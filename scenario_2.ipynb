# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.rent_vs_buy import (
    RentVsBuy,
    optimization_per_year,
    breakeven_per_year,
)

# %%
purchase_price = 1_500_000
va_funding_fee = 16_575
downpayment_amount = 174_000
downpayment = downpayment_amount / purchase_price
downpayment
# Out:
# 0.116

# %%
property_tax_rate = (1425.00 * 12) / purchase_price
property_tax_rate
# Out:
# 0.0114

# %%
home_owners_insurance_rate = 559.41 * 12 / purchase_price
home_owners_insurance_rate
# Out:
# 0.00447528

# %%
costs_of_buying_home = 17_999.67 / purchase_price
costs_of_buying_home
# Out:
# 0.011999779999999998

# %%
# We will reuse these kwargs later on.
kwargs = dict(
    home_price=purchase_price,
    financed_fees=va_funding_fee,
    years=30,
    mortgage_rate=0.06625,
    downpayment=downpayment,
    # Using VA loan, so no PMI.
    pmi=0.0,
    length_of_mortgage=30,
    home_price_growth_rate=0.08,
    rent_growth_rate=0.01,
    investment_return_rate=0.08,
    investment_tax_rate=0.20,
    inflation_rate=0.02,
    filing_jointly=True,
    property_tax_rate=property_tax_rate,
    marginal_tax_rate=0.2,
    costs_of_buying_home=costs_of_buying_home,
    costs_of_selling_home=0.06,
    maintenance_rate=0.001,
    home_owners_insurance_rate=home_owners_insurance_rate,
    monthly_utilities=0,
    monthly_common_fees=450,
    monthly_rent=3550,
    security_deposit=1,
    brokers_fee=0.00,
    renters_insurance_rate=0.01,
)
# Create our RentVsBuy calculator.
rent_vs_buy = RentVsBuy().calculate(**kwargs)
df = rent_vs_buy.df
df.to_clipboard()
print(rent_vs_buy.value.squeeze())
# Out:
# 1060799.721074134

# %%
breakeven_per_year(
    scalar="home_price_growth_rate",
    bounds=[0.0001, 0.1],
    start_year=1,
    end_year=41,
    kwargs=kwargs,
)
# Out:
#              fun status success          message         x nfev nit
# 1   64961.050738      0    True  Solution found.  0.099993   20  20
# 2       4.653448      0    True  Solution found.  0.093652   16  16
# 3       7.999759      0    True  Solution found.  0.077077   15  15
# 4       1.595347      0    True  Solution found.  0.071123   15  15
# 5       1.256996      0    True  Solution found.  0.068032   15  15
# 6       3.334921      0    True  Solution found.  0.066351   15  15
# 7       8.648522      0    True  Solution found.  0.065465   19  19
# 8      22.779923      0    True  Solution found.  0.065069   19  19
# 9      28.151847      0    True  Solution found.  0.065034   19  19
# 10     25.194292      0    True  Solution found.  0.065206   16  16
# 11      8.111524      0    True  Solution found.  0.065525   19  19
# 12     35.519464      0    True  Solution found.  0.065947   18  18
# 13     43.372682      0    True  Solution found.  0.066449   14  14
# 14     22.881214      0    True  Solution found.  0.067003   14  14
# 15     25.310526      0    True  Solution found.  0.067601   15  15
# 16      20.17595      0    True  Solution found.  0.068224   14  14
# 17     23.770669      0    True  Solution found.  0.068866   15  15
# 18     66.750077      0    True  Solution found.  0.069521   14  14
# 19     107.98282      0    True  Solution found.  0.070178   14  14
# 20     91.208794      0    True  Solution found.  0.070838   16  16
# 21     154.58607      0    True  Solution found.  0.071494   15  15
# 22      6.730875      0    True  Solution found.  0.072146   17  17
# 23    158.909345      0    True  Solution found.  0.072786   15  15
# 24       8.51641      0    True  Solution found.  0.073418   15  15
# 25    269.060264      0    True  Solution found.  0.074036   15  15
# 26    231.818295      0    True  Solution found.  0.074644   14  14
# 27    213.278308      0    True  Solution found.  0.075235   14  14
# 28    296.783505      0    True  Solution found.  0.075812   17  17
# 29    395.001759      0    True  Solution found.  0.076373   15  15
# 30    122.989456      0    True  Solution found.  0.076916   15  15
# 31    599.360578      0    True  Solution found.  0.077456   14  14
# 32      8.006496      0    True  Solution found.  0.077992   16  16
# 33    403.940179      0    True  Solution found.  0.078524   15  15
# 34      4.059304      0    True  Solution found.  0.079038   14  14
# 35    787.531434      0    True  Solution found.  0.079527   15  15
# 36    398.384464      0    True  Solution found.  0.079995   16  16
# 37   1034.650883      0    True  Solution found.  0.080441   17  17
# 38    1283.38016      0    True  Solution found.   0.08087   15  15
# 39    345.182155      0    True  Solution found.  0.081277   15  15
# 40    986.976915      0    True  Solution found.  0.081669   15  15

# %%
optimization_per_year(
    scalar="downpayment",
    bounds=[downpayment, 1.0],
    start_year=1,
    end_year=41,
    kwargs=kwargs,
)
# Out:
#                       fun status success          message  \
# 1    [-6438.240204035537]      0    True  Solution found.
# 2    [128918.64760217606]      0    True  Solution found.
# 3    [258472.49236327526]      0    True  Solution found.
# 4     [285245.7506146708]      0    True  Solution found.
# 5     [312288.2917549005]      0    True  Solution found.
# 6     [339440.1223149956]      0    True  Solution found.
# 7      [366512.693837286]      0    True  Solution found.
# 8     [393285.2649078071]      0    True  Solution found.
# 9     [419500.8560385974]      0    True  Solution found.
# 10   [444861.75487669837]      0    True  Solution found.
# 11    [469024.5249628518]      0    True  Solution found.
# 12   [513226.67158101406]      0    True  Solution found.
# 13    [574053.7549376856]      0    True  Solution found.
# 14    [635197.1438150536]      0    True  Solution found.
# 15    [696275.9977317913]      0    True  Solution found.
# 16    [756843.4556011595]      0    True  Solution found.
# 17    [816380.2131539029]      0    True  Solution found.
# 18    [874282.9999614498]      0    True  Solution found.
# 19    [929859.7808740148]      0    True  Solution found.
# 20    [982312.9739587428]      0    True  Solution found.
# 21   [1030726.9807654014]      0    True  Solution found.
# 22   [1074058.4017523136]      0    True  Solution found.
# 23   [1111121.5823467625]      0    True  Solution found.
# 24   [1140563.4298017062]      0    True  Solution found.
# 25   [1160856.8299450185]      0    True  Solution found.
# 26   [1170267.0914387088]      0    True  Solution found.
# 27    [1170131.086691849]      0    True  Solution found.
# 28   [1152098.4333055913]      0    True  Solution found.
# 29   [1116579.6274939943]      0    True  Solution found.
# 30   [1060791.2665049788]      0    True  Solution found.
# 31    [978418.7549096793]      0    True  Solution found.
# 32    [861887.7060188428]      0    True  Solution found.
# 33    [706886.9020215534]      0    True  Solution found.
# 34   [513892.21836223826]      0    True  Solution found.
# 35    [280970.7613324076]      0    True  Solution found.
# 36     [2799.60172650218]      0    True  Solution found.
# 37  [-326552.87870819494]      0    True  Solution found.
# 38   [-713691.3591098711]      0    True  Solution found.
# 39   [-1165964.443742361]      0    True  Solution found.
# 40  [-1691542.6529181898]      0    True  Solution found.
#
#                         x nfev nit
# 1     [0.999994822095504]   25  25
# 2     [0.999994822095504]   25  25
# 3     [0.999994822095504]   25  25
# 4     [0.999994822095504]   25  25
# 5     [0.999994822095504]   25  25
# 6     [0.999994822095504]   25  25
# 7     [0.999994822095504]   25  25
# 8     [0.999994822095504]   25  25
# 9     [0.999994822095504]   25  25
# 10    [0.999994822095504]   25  25
# 11    [0.999994822095504]   25  25
# 12   [0.1209285937316756]   25  25
# 13   [0.1209285937316756]   25  25
# 14   [0.1209285937316756]   25  25
# 15    [0.120926720677015]   26  26
# 16  [0.12092667155083618]   25  25
# 17  [0.12092647642268156]   25  25
# 18  [0.12092994317672653]   25  25
# 19  [0.12093010001089355]   25  25
# 20   [0.1209278285486743]   25  25
# 21  [0.12092729755237296]   25  25
# 22  [0.12092802741707741]   25  25
# 23  [0.12092643724078349]   25  25
# 24  [0.12092730265401778]   25  25
# 25   [0.1209271558889994]   23  23
# 26  [0.12093021884882517]   23  23
# 27  [0.11600519101608192]   26  26
# 28  [0.11600519101608192]   26  26
# 29  [0.11600519101608192]   26  26
# 30  [0.11600519101608192]   26  26
# 31  [0.11600519101608192]   26  26
# 32  [0.11600519101608192]   26  26
# 33  [0.11600519101608192]   26  26
# 34  [0.11600519101608192]   26  26
# 35  [0.11600519101608192]   26  26
# 36  [0.11600519101608192]   26  26
# 37  [0.11600519101608192]   26  26
# 38  [0.11600519101608192]   26  26
# 39  [0.11600519101608192]   26  26
# 40  [0.11600519101608192]   26  26
